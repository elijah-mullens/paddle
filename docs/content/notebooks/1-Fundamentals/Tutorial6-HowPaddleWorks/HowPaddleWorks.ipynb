# %% [markdown]
# # How Paddle Works
#
# <div class="alert alert-block alert-success">
#
# Schematic Flow Chart of how the PADDLE code works (and how all the different modules interface)
#
# Introduction to basics of hydrodynamics (underlying theory of how the code works, now that you have seen how the code works)
#
# List of papers that have used code paddle is based on. More explanation of snapy, canoe, and kintera.
#
# Meant to introduce the basics of a hydro code to Exoplanet people, and what makes Paddle ‘different’ from other dynamical codes
#
#
# </div>
